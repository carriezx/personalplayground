# %% [markdown]
# <h1 align="center"> Introduction to Statistics with Python </h1>

# %% [markdown]
# Comparing Models using AIC and BIC
# ===

# %%
# %reset -f
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import scipy.stats as stats
import statsmodels.api as sm
import seaborn as sns
import math as m
import scipy as sp
from statsmodels.stats.anova import anova_lm

import warnings
warnings.filterwarnings('ignore')

# %%
# Will fix figure size for this notebook
plt.rcParams["figure.figsize"] = (6,4)

# %% [markdown]
# Retrieving Data
# ===

# %%
# Retriving data which has been downloaded from yahoo and saved as CSV.

df1 = pd.read_csv('GSRet.csv', index_col = 0)
df2 = pd.read_csv('LogVol.csv', index_col = 0)

# %%
# GS daily log return
GSrtn = df1['x']
# Log of GS volume traded
GSLogVol = df2['x']
# GS volume traded
GSVol = np.exp(GSLogVol)

# %%
# Plot data 
plt.scatter(x=GSVol,y=GSrtn)
plt.xlabel('Daily GS Volume')
plt.ylabel('Daily GS Log Returns')
plt.grid()
#plt.savefig("GS_WeightedLinearReg")

# %%
# Importing stats models and sklearn modules

from statsmodels.stats.anova import anova_lm
from sklearn import linear_model
from statsmodels.sandbox.regression.predstd import wls_prediction_std
import statsmodels.api as sm
from statsmodels.nonparametric.smoothers_lowess import lowess
import statsmodels.formula.api as smf

# %% [markdown]
# Apply a set of regressions and compare models
# ====

# %%
#Let's look Volume being a predictor input for the Returns in a linear regression

X1 = GSVol.values
X1 = sm.add_constant(X1) # Need to add a constant to account for intercept
y = GSrtn

# Initialise model, fit and print results, including conf. interval

model = sm.OLS(y, X1)
lm_0 = model.fit()
res = lm_0.resid
resSqr = res**2
print(lm_0.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      x   R-squared:                       0.004
# Model:                            OLS   Adj. R-squared:                  0.003
# Method:                 Least Squares   F-statistic:                     11.91
# Date:                Thu, 17 Apr 2025   Prob (F-statistic):           0.000565
# Time:                        18:25:11   Log-Likelihood:                 7510.7
# No. Observations:                3216   AIC:                        -1.502e+04
# Df Residuals:                    3214   BIC:                        -1.501e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0013      0.001      2.315      0.021       0.000       0.002
# x1          -1.88e-10   5.45e-11     -3.451      0.001   -2.95e-10   -8.12e-11
# ==============================================================================
# Omnibus:                      936.881   Durbin-Watson:                   2.085
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            36780.366
# Skew:                           0.671   Prob(JB):                         0.00
# Kurtosis:                      19.513   Cond. No.                     1.37e+07
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.37e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# Plot results
plt.figure(figsize=(12,5))
plt.subplot(1,2, 1)

x = GSVol
y = GSrtn
y_fitted_model0 = lm_0.fittedvalues
plt.scatter(x=x,y=y)
plt.grid()
plt.xlabel('Daily GS Volume')
plt.ylabel('Daily GS Log Returns')
plt.scatter(x,y_fitted_model0, color = 'red', label = 'OLS fit')
plt.legend()
plt.subplot(1,2, 2)
yfit = lm_0.fittedvalues
plt.scatter(x=x,y=resSqr)
plt.xlabel('GS Traded Vol')
plt.ylabel('Residual Square')
plt.grid()
#plt.savefig("Shape of ResSquare")

# %% [markdown]
# Objective is to find a model for res^2
# ====

# %% [markdown]
# - Given the Linear Regression above, can we try to model the squared of residuals as a proxy for variance and hence adjust the regression with appropriate weights?
#
# - We can try a series of models and use our knowledge on model selection to pick the best one.

# %%
# Fit a linear regression on square of residuals against Volume


X1 = GSVol.values
X1 = sm.add_constant(X1)
y = GSrtn
model = sm.OLS(y, X1)
lm_0 = model.fit()

res = lm_0.resid
resSqr = res**2

y = resSqr.values
model = sm.OLS(y, X1)
lm_var1 = model.fit()
print(lm_var1.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.237
# Model:                            OLS   Adj. R-squared:                  0.237
# Method:                 Least Squares   F-statistic:                     997.8
# Date:                Tue, 18 Oct 2022   Prob (F-statistic):          5.85e-191
# Time:                        13:37:08   Log-Likelihood:                 15327.
# No. Observations:                3216   AIC:                        -3.065e+04
# Df Residuals:                    3214   BIC:                        -3.064e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0005   4.88e-05     -9.853      0.000      -0.001      -0.000
# x1          1.514e-10   4.79e-12     31.588      0.000    1.42e-10    1.61e-10
# ==============================================================================
# Omnibus:                     6001.965   Durbin-Watson:                   1.899
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         10922098.938
# Skew:                          13.825   Prob(JB):                         0.00
# Kurtosis:                     287.154   Cond. No.                     1.37e+07
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.37e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# Finding the bSpline / natural cubic spline in Python
import patsy
from patsy import dmatrix

# %%
# Data
x = GSVol
y = resSqr

# Use Natural Spline Regression
data = {"x": x}
x_ns_5 = dmatrix("cr(x, df=5)", data)
x_ns_5 = np.asarray(x_ns_5)
x_ns_5 = sm.add_constant(x_ns_5)

model = sm.OLS(y, x_ns_5)
lm_var2 = model.fit()
print(lm_var2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.250
# Model:                            OLS   Adj. R-squared:                  0.249
# Method:                 Least Squares   F-statistic:                     267.5
# Date:                Thu, 17 Apr 2025   Prob (F-statistic):          1.23e-198
# Time:                        18:30:13   Log-Likelihood:                 15354.
# No. Observations:                3216   AIC:                        -3.070e+04
# Df Residuals:                    3211   BIC:                        -3.067e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0028      0.000     14.234      0.000       0.002       0.003
# x1            -0.0032      0.000    -10.992      0.000      -0.004      -0.003
# x2            -0.0025      0.000    -12.215      0.000      -0.003      -0.002
# x3            -0.0027      0.000    -14.131      0.000      -0.003      -0.002
# x4            -0.0024      0.000    -12.301      0.000      -0.003      -0.002
# x5             0.0136      0.001     14.788      0.000       0.012       0.015
# ==============================================================================
# Omnibus:                     5936.990   Durbin-Watson:                   1.930
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         10466255.180
# Skew:                          13.498   Prob(JB):                         0.00
# Kurtosis:                     281.168   Cond. No.                     8.41e+15
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 5.11e-28. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
x = GSVol
y = resSqr

model_fitted_y = lm_var2.fittedvalues
plt.scatter(x=x,y=y)
plt.grid()
plt.ylabel('ResSqr')
plt.xlabel('Volume')
plt.scatter(x,model_fitted_y, color = 'red')
plt.show()

# %%
# Data
x = np.log(GSVol.values)
y = resSqr

# Use Natural Spline Regression on log GS Volume
data = {"x": x}
logx_ns_5 = dmatrix("cr(x, df=5)", data)
logx_ns_5 = np.asarray(logx_ns_5)
logx_ns_5 = sm.add_constant(logx_ns_5)

model = sm.OLS(y, logx_ns_5)
lm_var3 = model.fit()
print(lm_var3.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.266
# Model:                            OLS   Adj. R-squared:                  0.265
# Method:                 Least Squares   F-statistic:                     291.4
# Date:                Tue, 18 Oct 2022   Prob (F-statistic):          5.03e-214
# Time:                        13:37:08   Log-Likelihood:                 15390.
# No. Observations:                3216   AIC:                        -3.077e+04
# Df Residuals:                    3211   BIC:                        -3.074e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0028      0.000     20.466      0.000       0.003       0.003
# x1            -0.0020      0.000     -3.987      0.000      -0.003      -0.001
# x2            -0.0028      0.000    -16.176      0.000      -0.003      -0.002
# x3            -0.0024      0.000    -19.115      0.000      -0.003      -0.002
# x4            -0.0027      0.000    -17.195      0.000      -0.003      -0.002
# x5             0.0128      0.000     29.437      0.000       0.012       0.014
# ==============================================================================
# Omnibus:                     5846.554   Durbin-Watson:                   1.961
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          9824049.793
# Skew:                          13.054   Prob(JB):                         0.00
# Kurtosis:                     272.504   Cond. No.                     6.57e+15
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.12e-28. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
x = GSVol
y = resSqr

model_fitted_y = lm_var3.fittedvalues
plt.scatter(x=x,y=y)
plt.grid()
plt.ylabel('ResSqr')
plt.xlabel('Volume')
plt.scatter(x,model_fitted_y, color = 'red')
plt.show()

# %%
# Data
x = np.log(GSVol).values
y = resSqr

# Use Natural Spline Regression on x and ln x combined
data = {"x": x}
logx_ns_5 = dmatrix("cr(x, df=5)", data)
logx_ns_5 = np.asarray(x_ns_5)
X_logx_ns_5_log = np.concatenate((x_ns_5,logx_ns_5), axis=1)
X_logx_ns_5_log.shape

model = sm.OLS(y, X_logx_ns_5_log)
lm_var4 = model.fit()
print(lm_var4.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.250
# Model:                            OLS   Adj. R-squared:                  0.249
# Method:                 Least Squares   F-statistic:                     267.5
# Date:                Tue, 18 Oct 2022   Prob (F-statistic):          1.23e-198
# Time:                        13:37:08   Log-Likelihood:                 15354.
# No. Observations:                3216   AIC:                        -3.070e+04
# Df Residuals:                    3211   BIC:                        -3.067e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0014   9.69e-05     14.234      0.000       0.001       0.002
# x1            -0.0016      0.000    -10.992      0.000      -0.002      -0.001
# x2            -0.0013      0.000    -12.215      0.000      -0.001      -0.001
# x3            -0.0014   9.64e-05    -14.131      0.000      -0.002      -0.001
# x4            -0.0012   9.71e-05    -12.301      0.000      -0.001      -0.001
# x5             0.0068      0.000     14.788      0.000       0.006       0.008
# x6             0.0014   9.69e-05     14.234      0.000       0.001       0.002
# x7            -0.0016      0.000    -10.992      0.000      -0.002      -0.001
# x8            -0.0013      0.000    -12.215      0.000      -0.001      -0.001
# x9            -0.0014   9.64e-05    -14.131      0.000      -0.002      -0.001
# x10           -0.0012   9.71e-05    -12.301      0.000      -0.001      -0.001
# x11            0.0068      0.000     14.788      0.000       0.006       0.008
# ==============================================================================
# Omnibus:                     5936.990   Durbin-Watson:                   1.930
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         10466255.180
# Skew:                          13.498   Prob(JB):                         0.00
# Kurtosis:                     281.168   Cond. No.                     5.47e+18
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.42e-33. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
x = GSVol
y = resSqr
model_fitted_y = lm_var4.fittedvalues
plt.scatter(x=x,y=y)
plt.grid()
plt.ylabel('ResSqr')
plt.xlabel('Volume')
plt.scatter(x,model_fitted_y, color = 'red')
plt.show()

# %%
# Data
x = GSVol
y = resSqr

# Use Natural Spline Regression
data = {"x": x}
x_ns_10 = dmatrix("cr(x, df=10)", data)
x_ns_10 = np.asarray(x_ns_10)
x_ns_10 = sm.add_constant(x_ns_10)

model = sm.OLS(y, x_ns_10)
lm_var5 = model.fit()
print(lm_var5.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.269
# Model:                            OLS   Adj. R-squared:                  0.267
# Method:                 Least Squares   F-statistic:                     131.3
# Date:                Tue, 18 Oct 2022   Prob (F-statistic):          5.09e-211
# Time:                        13:37:09   Log-Likelihood:                 15396.
# No. Observations:                3216   AIC:                        -3.077e+04
# Df Residuals:                    3206   BIC:                        -3.071e+04
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0014      0.000     11.916      0.000       0.001       0.002
# x1            -0.0014      0.001     -2.332      0.020      -0.003      -0.000
# x2            -0.0014      0.000     -8.307      0.000      -0.002      -0.001
# x3            -0.0013      0.000     -9.364      0.000      -0.002      -0.001
# x4            -0.0013      0.000     -8.139      0.000      -0.002      -0.001
# x5            -0.0012      0.000     -7.671      0.000      -0.001      -0.001
# x6            -0.0013      0.000     -8.487      0.000      -0.002      -0.001
# x7            -0.0009      0.000     -6.012      0.000      -0.001      -0.001
# x8            -0.0013      0.000     -9.875      0.000      -0.002      -0.001
# x9            -0.0006      0.000     -4.218      0.000      -0.001      -0.000
# x10            0.0121      0.001     11.733      0.000       0.010       0.014
# ==============================================================================
# Omnibus:                     5819.242   Durbin-Watson:                   1.962
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          9596433.619
# Skew:                          12.924   Prob(JB):                         0.00
# Kurtosis:                     269.359   Cond. No.                     5.83e+15
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 3.6e-28. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
x = GSVol
y = resSqr

model_fitted_y = lm_var5.fittedvalues
plt.scatter(x=x,y=y)
plt.grid()
plt.ylabel('ResSqr')
plt.xlabel('Volume')
plt.scatter(x,model_fitted_y, color = 'red')
plt.show()

# %%
# Data
x = np.log(GSVol).values
y = resSqr

# Use Natural Spline Regression
data = {"x": x}
logx_ns_10 = dmatrix("cr(x, df=10)", data)
logx_ns_10 = np.asarray(logx_ns_10)
logx_ns_10 = sm.add_constant(logx_ns_10)

model = sm.OLS(y, logx_ns_10)
lm_var6 = model.fit()
print(lm_var6.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.275
# Model:                            OLS   Adj. R-squared:                  0.273
# Method:                 Least Squares   F-statistic:                     135.0
# Date:                Tue, 18 Oct 2022   Prob (F-statistic):          3.17e-216
# Time:                        13:37:09   Log-Likelihood:                 15408.
# No. Observations:                3216   AIC:                        -3.080e+04
# Df Residuals:                    3206   BIC:                        -3.074e+04
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0019      0.000     16.677      0.000       0.002       0.002
# x1            -0.0019      0.001     -2.071      0.038      -0.004      -0.000
# x2            -0.0018      0.000    -11.890      0.000      -0.002      -0.002
# x3            -0.0018      0.000    -14.536      0.000      -0.002      -0.002
# x4            -0.0017      0.000    -11.000      0.000      -0.002      -0.001
# x5            -0.0017      0.000    -11.004      0.000      -0.002      -0.001
# x6            -0.0017      0.000    -10.919      0.000      -0.002      -0.001
# x7            -0.0015      0.000     -9.828      0.000      -0.002      -0.001
# x8            -0.0014      0.000    -10.995      0.000      -0.002      -0.001
# x9            -0.0011      0.000     -7.455      0.000      -0.001      -0.001
# x10            0.0166      0.001     24.557      0.000       0.015       0.018
# ==============================================================================
# Omnibus:                     5812.106   Durbin-Watson:                   1.991
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          9693454.986
# Skew:                          12.882   Prob(JB):                         0.00
# Kurtosis:                     270.723   Cond. No.                     6.60e+15
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 8.63e-29. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
x = GSVol
y = resSqr

model_fitted_y = lm_var6.fittedvalues
plt.scatter(x=x,y=y)
plt.grid()
plt.ylabel('ResSqr')
plt.xlabel('Volume')
plt.scatter(x,model_fitted_y, color = 'red')
plt.show()

# %%
# Data
x = np.log(GSVol).values
y = resSqr
# Use Natural Spline Regression
data = {"x": x}
logx_ns_10 = dmatrix("cr(x, df=10)", data)
logx_ns_10 = np.asarray(logx_ns_10)
ns_10_logx_ns_10 = np.concatenate((x_ns_10,logx_ns_10), axis=1)

model = sm.OLS(y, ns_10_logx_ns_10)
lm_var7 = model.fit()
print(lm_var7.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.305
# Model:                            OLS   Adj. R-squared:                  0.301
# Method:                 Least Squares   F-statistic:                     77.76
# Date:                Tue, 18 Oct 2022   Prob (F-statistic):          6.60e-236
# Time:                        13:37:09   Log-Likelihood:                 15476.
# No. Observations:                3216   AIC:                        -3.091e+04
# Df Residuals:                    3197   BIC:                        -3.080e+04
# Df Model:                          18
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       5.986e+08   4.79e+09      0.125      0.901    -8.8e+09    9.99e+09
# x1          5.854e+07   4.69e+08      0.125      0.901    -8.6e+08    9.77e+08
# x2          5.854e+07   4.69e+08      0.125      0.901    -8.6e+08    9.77e+08
# x3          5.854e+07   4.69e+08      0.125      0.901    -8.6e+08    9.77e+08
# x4          5.854e+07   4.69e+08      0.125      0.901    -8.6e+08    9.77e+08
# x5          5.854e+07   4.69e+08      0.125      0.901    -8.6e+08    9.77e+08
# x6          5.854e+07   4.69e+08      0.125      0.901    -8.6e+08    9.77e+08
# x7          5.854e+07   4.69e+08      0.125      0.901    -8.6e+08    9.77e+08
# x8          5.854e+07   4.69e+08      0.125      0.901    -8.6e+08    9.77e+08
# x9          5.854e+07   4.69e+08      0.125      0.901    -8.6e+08    9.77e+08
# x10         5.854e+07   4.69e+08      0.125      0.901    -8.6e+08    9.77e+08
# x11        -7.094e+08   5.68e+09     -0.125      0.901   -1.18e+10    1.04e+10
# x12         5.227e+07   4.19e+08      0.125      0.901   -7.68e+08    8.73e+08
# x13         5.227e+07   4.19e+08      0.125      0.901   -7.68e+08    8.73e+08
# x14         5.227e+07   4.19e+08      0.125      0.901   -7.68e+08    8.73e+08
# x15         5.227e+07   4.19e+08      0.125      0.901   -7.68e+08    8.73e+08
# x16         5.227e+07   4.19e+08      0.125      0.901   -7.68e+08    8.73e+08
# x17         5.227e+07   4.19e+08      0.125      0.901   -7.68e+08    8.73e+08
# x18         5.227e+07   4.19e+08      0.125      0.901   -7.68e+08    8.73e+08
# x19         5.227e+07   4.19e+08      0.125      0.901   -7.68e+08    8.73e+08
# x20         5.227e+07   4.19e+08      0.125      0.901   -7.68e+08    8.73e+08
# x21         5.227e+07   4.19e+08      0.125      0.901   -7.68e+08    8.73e+08
# ==============================================================================
# Omnibus:                     5491.966   Durbin-Watson:                   2.043
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          7475404.902
# Skew:                          11.428   Prob(JB):                         0.00
# Kurtosis:                     238.083   Cond. No.                     2.19e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.88e-29. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
x = GSVol
y = resSqr

model_fitted_y = lm_var7.fittedvalues
plt.scatter(x=x,y=y)
plt.grid()
plt.ylabel('ResSqr')
plt.xlabel('Volume')
plt.scatter(x,model_fitted_y, color = 'red')
plt.show()

# %%
# Model selection with AIC/BIC

aic_values = [lm_var1.aic, lm_var2.aic,lm_var3.aic,lm_var4.aic,lm_var5.aic,lm_var6.aic,lm_var7.aic]
bic_values = [lm_var1.bic, lm_var2.bic,lm_var3.bic,lm_var4.bic,lm_var5.bic,lm_var6.bic,lm_var7.bic]

models = ['var1','var2','var3','var4','var5','var6','var7']
model_selection = pd.DataFrame(np.array([models,aic_values,bic_values]).T, columns = ['model','aic','bic'])
model_selection
# Out:
#   model                  aic                  bic
# 0  var1  -30649.126277176532  -30636.974489915934
# 1  var2  -30698.463527801672  -30668.084059650177
# 2  var3   -30769.56530883898  -30739.185840687485
# 3  var4  -30698.463527801672  -30668.084059650177
# 4  var5  -30772.782538582585  -30712.023602279598
# 5  var6   -30796.97547410545  -30736.216537802462
# 6  var7  -30913.428981154277  -30797.987002178597

# %%
x = GSVol
y = resSqr

y_5 = lm_var5.fittedvalues
y_4 = lm_var4.fittedvalues
y_7 = lm_var7.fittedvalues

plt.scatter(x=x,y=y)
plt.grid()
plt.ylabel('ResSqr')
plt.xlabel('Daily GS Volume')
plt.scatter(x,y_4, color = "red",label = "nspline df = 5")
plt.scatter(x,y_7,label = "nspline and log ns df = 10")
plt.scatter(x,y_5, label = "nspline df = 10")
plt.legend()
#plt.savefig("GS_various_param_res2")

# %% [markdown]
# Weighted Regression
# ====

# %%
# Unweighted regression
X1 = GSVol.values
X1 = sm.add_constant(X1) 
model = sm.OLS(y, X1)
lm_0 = model.fit()

# Plot results
model_fitted_y = lm_0.fittedvalues
x = GSVol
y = GSrtn
plt.scatter(x=x,y=y)
plt.grid()
plt.ylabel('Returns')
plt.xlabel('Volume')
plt.scatter(x,model_fitted_y, color = 'red')
plt.show()

# %%
#Rescaling returns by Volume - homoskedastic?

x = GSVol
temp = (1+GSVol.values)
y = GSrtn.values
y_temp = y/temp

plt.scatter(x=x,y=y_temp)
plt.grid()
plt.ylabel('Returns')
plt.xlabel('Volume')
plt.ylim(( -1.5e-8,1.5e-8))
plt.show()

# %%
#Easier scale to observe

x_log = np.log(GSVol)
temp = (1+GSVol.values)
y = GSrtn.values
y_temp = y/temp
plt.scatter(x=x_log,y=y_temp)
plt.grid()
plt.ylabel('Returns')
plt.xlabel('Volume')
plt.ylim((-1.5e-8,1.5e-8))
plt.show()

# %%
# Weighted regression

X1 = GSVol.values
X1 = sm.add_constant(X1) 
y = GSrtn
model = sm.WLS(y, X1, weights=1/(1+GSVol)**2)
lm_wls = model.fit()
print(lm_wls.summary())

# Plot results
model_fitted_y = lm_wls.fittedvalues
x = GSVol
y = GSrtn
plt.scatter(x=x,y=y)
plt.grid()
plt.ylabel('Returns')
plt.xlabel('Volume')
plt.scatter(x,model_fitted_y, color = 'red')
plt.show()
# Out:
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:                      x   R-squared:                       0.000
# Model:                            WLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                    0.8175
# Date:                Tue, 18 Oct 2022   Prob (F-statistic):              0.366
# Time:                        13:37:10   Log-Likelihood:                 8620.0
# No. Observations:                3216   AIC:                        -1.724e+04
# Df Residuals:                    3214   BIC:                        -1.722e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0007      0.000      1.972      0.049    4.19e-06       0.001
# x1         -1.026e-10   1.14e-10     -0.904      0.366   -3.25e-10     1.2e-10
# ==============================================================================
# Omnibus:                       48.956   Durbin-Watson:                   2.133
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               82.679
# Skew:                          -0.109   Prob(JB):                     1.11e-18
# Kurtosis:                       3.755   Cond. No.                     6.22e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 8.32e-11. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# Try and find a model for the variance directly
# ===
# - By using the models above, we can choose a fitted curve which best describes the Residual Squares at every point x.
# - This approximation can therefore be used as an optimal weight to minimise variance under WLS. As seen in Lectures, the optimal choise is $w_i = 1/\sigma_i^2$.

# %%
# Choosing the most promising model as per above.

print(lm_var7.summary());
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.305
# Model:                            OLS   Adj. R-squared:                  0.301
# Method:                 Least Squares   F-statistic:                     77.76
# Date:                Tue, 18 Oct 2022   Prob (F-statistic):          6.60e-236
# Time:                        13:37:10   Log-Likelihood:                 15476.
# No. Observations:                3216   AIC:                        -3.091e+04
# Df Residuals:                    3197   BIC:                        -3.080e+04
# Df Model:                          18
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       5.986e+08   4.79e+09      0.125      0.901    -8.8e+09    9.99e+09
# x1          5.854e+07   4.69e+08      0.125      0.901    -8.6e+08    9.77e+08
# x2          5.854e+07   4.69e+08      0.125      0.901    -8.6e+08    9.77e+08
# x3          5.854e+07   4.69e+08      0.125      0.901    -8.6e+08    9.77e+08
# x4          5.854e+07   4.69e+08      0.125      0.901    -8.6e+08    9.77e+08
# x5          5.854e+07   4.69e+08      0.125      0.901    -8.6e+08    9.77e+08
# x6          5.854e+07   4.69e+08      0.125      0.901    -8.6e+08    9.77e+08
# x7          5.854e+07   4.69e+08      0.125      0.901    -8.6e+08    9.77e+08
# x8          5.854e+07   4.69e+08      0.125      0.901    -8.6e+08    9.77e+08
# x9          5.854e+07   4.69e+08      0.125      0.901    -8.6e+08    9.77e+08
# x10         5.854e+07   4.69e+08      0.125      0.901    -8.6e+08    9.77e+08
# x11        -7.094e+08   5.68e+09     -0.125      0.901   -1.18e+10    1.04e+10
# x12         5.227e+07   4.19e+08      0.125      0.901   -7.68e+08    8.73e+08
# x13         5.227e+07   4.19e+08      0.125      0.901   -7.68e+08    8.73e+08
# x14         5.227e+07   4.19e+08      0.125      0.901   -7.68e+08    8.73e+08
# x15         5.227e+07   4.19e+08      0.125      0.901   -7.68e+08    8.73e+08
# x16         5.227e+07   4.19e+08      0.125      0.901   -7.68e+08    8.73e+08
# x17         5.227e+07   4.19e+08      0.125      0.901   -7.68e+08    8.73e+08
# x18         5.227e+07   4.19e+08      0.125      0.901   -7.68e+08    8.73e+08
# x19         5.227e+07   4.19e+08      0.125      0.901   -7.68e+08    8.73e+08
# x20         5.227e+07   4.19e+08      0.125      0.901   -7.68e+08    8.73e+08
# x21         5.227e+07   4.19e+08      0.125      0.901   -7.68e+08    8.73e+08
# ==============================================================================
# Omnibus:                     5491.966   Durbin-Watson:                   2.043
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          7475404.902
# Skew:                          11.428   Prob(JB):                         0.00
# Kurtosis:                     238.083   Cond. No.                     2.19e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.88e-29. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
model_fitted_y = lm_var7.fittedvalues
plt.scatter(x=GSVol,y=resSqr)
plt.grid()
plt.ylabel('ResSqr')
plt.xlabel('Volume')
plt.scatter(x=GSVol,y=np.abs(model_fitted_y), color = 'red')
plt.show()

# %%
model_fitted_y = lm_var7.fittedvalues
plt.grid()
plt.ylabel('ResSqr')
plt.xlabel('Volume')
plt.scatter(x=GSVol,y=1/np.abs(model_fitted_y), color = 'red')
plt.ylim((0,5.0e4))
plt.show()

# %% [markdown]
# Seeking Homoscedasticity
# ===

# %%
# Taking the absolute value in case there are negative values
fittedweights=1/(abs(lm_var7.fittedvalues))

# %%
# Plotting in log scale x and visualising effect of scaling errors 
# with fitted model for variance.

x_log = np.log(GSVol)
y_temp = res*np.sqrt(fittedweights)

plt.scatter(x=x_log,y=y_temp)
plt.grid()
plt.ylabel('resSqrtFittW')
plt.xlabel('Volume')
#plt.savefig("WhiteNoise2")

# The plot below seems homogeneous around the mean.
# Out:
# Text(0.5, 0, 'Volume')

# %% [markdown]
# Using this knowledge to build the WLS
# ===
#
# - Weighted regression of original model GSrtn as function of GSVol

# %%
# Weighted Linear Regression 

fittedweights=1/(abs(lm_var7.fittedvalues))

X1 = GSVol.values
X1 = sm.add_constant(X1) 
y = GSrtn
model = sm.WLS(y, X1, weights=fittedweights)
lm_wls_2 = model.fit()
print(lm_wls_2.summary())
# Out:
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:                      x   R-squared:                       0.005
# Model:                            WLS   Adj. R-squared:                  0.004
# Method:                 Least Squares   F-statistic:                     14.55
# Date:                Tue, 18 Oct 2022   Prob (F-statistic):           0.000139
# Time:                        13:37:11   Log-Likelihood:                 8734.8
# No. Observations:                3216   AIC:                        -1.747e+04
# Df Residuals:                    3214   BIC:                        -1.745e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0019      0.000      5.762      0.000       0.001       0.003
# x1         -3.224e-10   8.45e-11     -3.814      0.000   -4.88e-10   -1.57e-10
# ==============================================================================
# Omnibus:                       86.318   Durbin-Watson:                   2.100
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              206.302
# Skew:                           0.051   Prob(JB):                     1.59e-45
# Kurtosis:                       4.237   Cond. No.                     6.23e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.23e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# Plot results
model_fitted_y = lm_wls_2.fittedvalues
x = GSVol
y = GSrtn
plt.scatter(x=x,y=y)
plt.grid()
plt.ylabel('Returns')
plt.xlabel('Volume')
plt.scatter(x,model_fitted_y, color = 'red')
plt.show()

# %%
lm_wls_2.params
# Out:
# const    1.927792e-03
# x1      -3.224476e-10
# dtype: float64

# %%
lm_0.params
# Out:
# const   -4.810017e-04
# x1       1.514245e-10
# dtype: float64

# %%
x = GSVol

y_fitted_model0 = lm_0.fittedvalues
model_fitted_y = lm_wls_2.fittedvalues
x = GSVol
y = GSrtn
plt.scatter(x=x,y=y)
plt.grid()
plt.ylabel('Returns')
plt.xlabel('Volume')
plt.scatter(x,model_fitted_y, color = 'red', label = 'Weighted LS')
plt.scatter(x,y_fitted_model0, color = "orange",label = "Original OLS")
plt.legend()
#plt.savefig("FinalWLS")

# %%
np.random.seed(17)

mu = 0
std = 1

a = 2
b = 0.5

# Create random variable from distribution used
rv = stats.norm(mu,std)
n = 200
    
def f(x,rv,n1,n2,n3):
    n = x.size
    y = np.zeros(n)
    y_data = np.zeros(n)
    z = rv.rvs(size = n)
    for i in range(n1):
        y_data[i] = a*x[i]+b + 50*z[i]
        y[i] = a*x[i]+b
    for i in range(n1,n2):
        y_data[i] = a*x[i]+b + 500*z[i]*z[i]
        y[i] = a*x[i]+b
    return y_data,y

# %%
x = np.linspace(1,100,100)
y_data,y = f(x,rv,50,100,1010)
type(y)
# Out:
# numpy.ndarray

# %%
plt.scatter(x,y)
plt.scatter(x,y_data)
plt.grid()

# %%
X1 = x
X1 = sm.add_constant(X1) # Need to add a constant to account for intercept
y = y_data
model = sm.OLS(y, X1)
test = model.fit()
print(test.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.188
# Model:                            OLS   Adj. R-squared:                  0.179
# Method:                 Least Squares   F-statistic:                     22.65
# Date:                Tue, 18 Oct 2022   Prob (F-statistic):           6.71e-06
# Time:                        13:37:12   Log-Likelihood:                -819.12
# No. Observations:                 100   AIC:                             1642.
# Df Residuals:                      98   BIC:                             1647.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -277.5997    177.759     -1.562      0.122    -630.356      75.157
# x1            14.5432      3.056      4.759      0.000       8.479      20.608
# ==============================================================================
# Omnibus:                      105.994   Durbin-Watson:                   1.838
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1153.526
# Skew:                           3.669   Prob(JB):                    3.27e-251
# Kurtosis:                      17.934   Cond. No.                         117.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Plot results
plt.figure(figsize=(12,5))
plt.subplot(1,2, 1)
model_fitted_y = test.fittedvalues
x = x
y = y_data
plt.scatter(x=x,y=y)
plt.grid()
plt.ylabel('')
plt.xlabel('')
plt.scatter(x,model_fitted_y, color = 'red')
plt.subplot(1,2, 2)
x = model_fitted_y
y = test.resid
plt.scatter(x=x,y=y)
plt.grid()
plt.ylabel('')
# Out:
# Text(0, 0.5, '')

# %%
res2 = test.resid**2
x = x
x2 = x**2
y = res2

X1 = np.stack((x,x2))
X1 = sm.add_constant(X1.T) # Need to add a constant to account for intercept

# %%
model = sm.OLS(y, X1)
var1 = model.fit()
print(var1.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.066
# Model:                            OLS   Adj. R-squared:                  0.046
# Method:                 Least Squares   F-statistic:                     3.413
# Date:                Tue, 18 Oct 2022   Prob (F-statistic):             0.0370
# Time:                        13:37:12   Log-Likelihood:                -1634.4
# No. Observations:                 100   AIC:                             3275.
# Df Residuals:                      97   BIC:                             3283.
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -2.659e+04    4.6e+05     -0.058      0.954   -9.39e+05    8.86e+05
# x1           473.2052   1930.233      0.245      0.807   -3357.774    4304.184
# x2             1.4886      1.954      0.762      0.448      -2.390       5.367
# ==============================================================================
# Omnibus:                      148.888   Durbin-Watson:                   2.081
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             5183.900
# Skew:                           5.499   Prob(JB):                         0.00
# Kurtosis:                      36.514   Cond. No.                     8.44e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 8.44e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
resVar1 = var1.resid
fitVar1 = var1.fittedvalues

plt.scatter(x,res2)
plt.scatter(x,fitVar1)
plt.title('x vs resSquare', fontsize = 15)
plt.grid()

# %%
# Taking the absolute value in case there are negative values
fittedweights=1/(abs(fitVar1))

X1 = x
X1 = sm.add_constant(x) # Need to add a constant to account for intercept
y = y_data
model = sm.WLS(y, X1, weights=fittedweights)
wls_1 = model.fit()
print(wls_1.summary())
# Out:
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.197
# Model:                            WLS   Adj. R-squared:                  0.189
# Method:                 Least Squares   F-statistic:                     24.12
# Date:                Tue, 18 Oct 2022   Prob (F-statistic):           3.63e-06
# Time:                        13:37:12   Log-Likelihood:                -752.32
# No. Observations:                 100   AIC:                             1509.
# Df Residuals:                      98   BIC:                             1514.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         46.3796     22.761      2.038      0.044       1.211      91.548
# x1             0.6129      0.125      4.911      0.000       0.365       0.861
# ==============================================================================
# Omnibus:                      101.635   Durbin-Watson:                   1.718
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              983.634
# Skew:                           3.511   Prob(JB):                    2.55e-214
# Kurtosis:                      16.666   Cond. No.                         188.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
plt.figure(figsize=(12,8))

x = x
y = y_data
plt.scatter(x=x,y=y)
plt.scatter(x,model_fitted_y, color = 'red')
plt.scatter(x,wls_1.fittedvalues, color = 'orange')
plt.grid()

# %%
wls_1.params
# Out:
# array([46.37957299,  0.61293704])

# %%
test.params
# Out:
# array([-277.59966985,   14.54317041])
